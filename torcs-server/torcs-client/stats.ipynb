# %%
from matplotlib import pyplot as plt
import seaborn as sns

loss_values = [2.0920e+07, 2.0863e+07, 1.8079e+07, 1.4730e+07, 1.2166e+07, 1.0169e+07, 8.6109e+06, 7.4254e+06, 1.00000e+06 * 6.5128,    5.8008e+06, 5.2571e+06, 1.00000e+06 * 4.8382, 1.00000e+06 * 4.5117, 4.2612e+06, 1.00000e+06 * 4.0736, 1.00000e+06 * 3.9160, 1.00000e+06 * 3.8011, 1.00000e+06 * 3.7167, 1.00000e+06 * 3.6413, 1.00000e+06 * 3.5956, 1.00000e+06 * 3.5493, 1.00000e+06 * 3.5221, 1.00000e+06 * 3.4920, 1.00000e+06 * 3.4802, 1.00000e+06 * 3.4639, 3.4486e+06, 3.4440e+06, 1.00000e+06 * 3.4315, 1.00000e+06 * 3.4273, 1.00000e+06 * 3.4216, 1.00000e+06 * 3.4252, 1.00000e+06 * 3.4211, 1.00000e+06 * 3.4159, 3.4207e+06, 3.4136e+06, 1.00000e+06 * 3.4153, 1.00000e+06 * 3.4161, 1.00000e+06 * 3.4122, 1.00000e+06 * 3.4119, 1.00000e+06 * 3.4151, 1.00000e+06 * 3.4142, 3.4172e+06, 1.00000e+06 * 3.4114, 1.00000e+06 * 3.4134, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4125, 1.00000e+06 * 3.4142, 1.00000e+06 * 3.4144, 1.00000e+06 * 3.4170, 1.00000e+06 * 3.4134, 1.00000e+06 * 3.4142, 1.00000e+06 * 3.4160, 3.4162e+06, 1.00000e+06 * 3.4164, 3.4166e+06, 1.00000e+06 * 3.4174, 3.4083e+06, 1.00000e+06 * 3.4095, 1.00000e+06 * 3.4101, 1.00000e+06 * 3.4100, 1.00000e+06 * 3.4108, 1.00000e+06 * 3.4108, 1.00000e+06 * 3.4111, 1.00000e+06 * 3.4100, 1.00000e+06 * 3.4100, 1.00000e+06 * 3.4100, 1.00000e+06 * 3.4101, 1.00000e+06 * 3.4101, 1.00000e+06 * 3.4102, 1.00000e+06 * 3.4102, 3.4102e+06, 1.00000e+06 * 3.4102, 1.00000e+06 * 3.4102, 1.00000e+06 * 3.4102, 1.00000e+06 * 3.4102, 1.00000e+06 * 3.4102, 1.00000e+06 * 3.4110, 1.00000e+06 * 3.4110, 3.4110e+06, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 3.4109e+06, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 3.4109e+06, 3.4109e+06, 3.4109e+06, 3.4109e+06, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109, 1.00000e+06 * 3.4109]

sns.set()
plt.plot(loss_values[:40])
plt.title('Mean squared error loss over SGD epochs \n (simple multi-layer perceptron)')
plt.xlabel('Epochs')
plt.ylabel('MSE loss')
plt.show()
